# %%
import matplotlib.pyplot as plt

# 数据
categories = ['Overall acc', 'precision', 'recall', 'f1', 'auc']
train_from_scratch = [0.6375, 0.596, 0.843, 0.699, 0.673]
finetuning = [0.6272, 0.582, 0.903, 0.708, 0.654]

# 设置颜色
colors = ['b', 'g', 'r', 'c', 'm']

# 设置柱状图宽度
bar_width = 0.35

# 设置x轴坐标位置
x = range(len(categories))

# 创建Train from scratch柱状图
plt.bar(x, train_from_scratch, bar_width, color='b', label='Train from scratch')

# 创建Fine-tuning柱状图
plt.bar([i + bar_width for i in x], finetuning, bar_width, color='g', label='Fine-tuning')

# 设置x轴标签
plt.xlabel('Metrics')
plt.xticks([i + bar_width / 2 for i in x], categories)

# 设置y轴标签
plt.ylabel('Values')

# 添加图例
plt.legend()

# 显示图表
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
categories = ['Overall acc', 'precision', 'recall', 'f1', 'auc']
train_cifar10 = [0.658, 0.596, 0.982, 0.742, 0.658]
train_imagenet_cifar10 = [0.611, 0.562, 0.995, 0.719, 0.611]

# 设置颜色
colors = ['b', 'g', 'r', 'c', 'm']

# 设置柱状图宽度
bar_width = 0.35

# 设置x轴坐标位置
x = np.arange(len(categories))

# 创建Train on CIFAR10柱状图
plt.bar(x - bar_width/2, train_cifar10, bar_width, color='b', label='Train on CIFAR10')

# 创建Train on Imagenet100, finetune on CIFAR10柱状图
plt.bar(x + bar_width/2, train_imagenet_cifar10, bar_width, color='g', label='Train on Imagenet100, finetune on CIFAR10')

# 设置x轴标签
plt.xlabel('Metrics')
plt.xticks(x, categories)

# 设置y轴标签
plt.ylabel('Values')

# 添加图例
plt.legend()

# 显示图表
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
categories = ['Overall acc', 'precision', 'recall', 'f1', 'auc']

# 不同训练方式的数据
train_cifar10 = [0.658, 0.596, 0.982, 0.742, 0.658]
train_imagenet_cifar10 = [0.611, 0.562, 0.995, 0.719, 0.611]

# 不同测试数据的数据
correct_test = [0.658, 0.596, 0.982, 0.742, 0.658]
confidence_test = [0.69, 0.635, 0.895, 0.743, 0.707]
entropy_test = [0.642, 0.61, 0.786, 0.687, 0.66]
modified_entropy_test = [0.69, 0.636, 0.886, 0.74, 0.707]

# 设置颜色
colors = ['b', 'g', 'r', 'c', 'm']

# 设置柱状图宽度
bar_width = 0.15

# 设置x轴坐标位置
x = np.arange(len(categories))

# 创建Train on CIFAR10柱状图
plt.bar(x - 2*bar_width, train_cifar10, bar_width, color='b', label='Train on CIFAR10')

# 创建Train on Imagenet100, finetune on CIFAR10柱状图
plt.bar(x - bar_width, train_imagenet_cifar10, bar_width, color='g', label='Train on Imagenet100, finetune on CIFAR10')

# 创建Correct Test柱状图
plt.bar(x, correct_test, bar_width, color='r', label='Correct Test')

# 创建Confidence Test柱状图
plt.bar(x + bar_width, confidence_test, bar_width, color='c', label='Confidence Test')

# 创建Entropy Test柱状图
plt.bar(x + 2*bar_width, entropy_test, bar_width, color='m', label='Entropy Test')

# 创建Modified Entropy Test柱状图
plt.bar(x + 3*bar_width, modified_entropy_test, bar_width, color='y', label='Modified Entropy Test')

# 设置x轴标签
plt.xlabel('Metrics')
plt.xticks(x, categories)

# 设置y轴标签
plt.ylabel('Values')

# 添加图例
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))

# 显示图表
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
categories = ["Black-box", "Correct", "Confidence", "Entropy", "Modified Entropy"]
overall_acc_train_from_scratch = [0.6375, 0.658, 0.69, 0.642, 0.69]
overall_acc_finetuning = [0.6272, 0.611, 0.654, 0.632, 0.655]

precision_train_from_scratch = [0.597, 0.596, 0.635, 0.61, 0.636]
precision_finetuning = [0.582, 0.562, 0.605, 0.591, 0.605]

recall_train_from_scratch = [0.843, 0.982, 0.895, 0.786, 0.886]
recall_finetuning = [0.903, 0.995, 0.89, 0.856, 0.891]

f1_train_from_scratch = [0.699, 0.742, 0.743, 0.687, 0.74]
f1_finetuning = [0.708, 0.719, 0.72, 0.699, 0.721]

auc_train_from_scratch = [0.673, 0.658, 0.707, 0.66, 0.707]
auc_finetuning = [0.654, 0.611, 0.658, 0.638, 0.658]

# 设置子图
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(8, 20))

# 颜色
colors = ['#1f77b4', '#ff7f0e']

# 绘制柱状图
for i, cat in enumerate(categories):
    ax = axes[i]
    x = np.arange(len(categories))
    width = 0.35
    ax.bar(x - width/2, [overall_acc_train_from_scratch[i], overall_acc_finetuning[i]], width, label='Train from scratch', color=colors[0])
    ax.bar(x + width/2, [overall_acc_finetuning[i], overall_acc_train_from_scratch[i]], width, label='Finetuning', color=colors[1])

    ax.set_ylabel(cat)
    ax.set_xticks(x)
    ax.set_xticklabels(["", ""])
    ax.legend()

# 设置标签
axes[0].set_xticklabels(["Overall Acc"])
axes[1].set_xticklabels(["Precision"])
axes[2].set_xticklabels(["Recall"])
axes[3].set_xticklabels(["F1"])
axes[4].set_xticklabels(["AUC"])

# 显示图例
axes[0].legend()

# 标题
plt.suptitle('Comparison between "Train from scratch" and "Finetuning"', fontsize=16)

# 显示图形
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 32
#      30 x = np.arange(len(categories))
#      31 width = 0.35
# ---> 32 ax.bar(x - width/2, [overall_acc_train_from_scratch[i], overall_acc_finetuning[i]], width, label='Train from scratch', color=colors[0])
#      33 ax.bar(x + width/2, [overall_acc_finetuning[i], overall_acc_train_from_scratch[i]], width, label='Finetuning', color=colors[1])
#      35 ax.set_ylabel(cat)
#
# File ~/.conda/envs/whhcp/lib/python3.11/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
categories = ["Black-box", "Correct", "Confidence", "Entropy", "Modified Entropy"]
methods = ["Train from scratch", "Finetuning"]

overall_acc = {
    "Train from scratch": [63.75, 65.8, 69, 64.2, 69],
    "Finetuning": [62.72, 61.1, 65.4, 63.2, 65.5]
}

precision = {
    "Train from scratch": [59.7, 59.6, 63.5, 61, 63.6],
    "Finetuning": [58.2, 56.2, 60.5, 59.1, 60.5]
}

recall = {
    "Train from scratch": [84.3, 98.2, 89.5, 78.6, 88.6],
    "Finetuning": [90.3, 99.5, 89, 85.6, 89.1]
}

f1 = {
    "Train from scratch": [69.9, 74.2, 74.3, 68.7, 74],
    "Finetuning": [70.8, 71.9, 72, 69.9, 72.1]
}

auc = {
    "Train from scratch": [67.3, 65.8, 70.7, 66, 70.7],
    "Finetuning": [65.4, 61.1, 65.8, 63.8, 65.8]
}

# 设置子图
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(8, 20))

# 颜色
colors = ['#1f77b4', '#ff7f0e']

# 绘制柱状图
for i, cat in enumerate(categories):
    ax = axes[i]
    x = np.arange(len(categories))
    width = 0.35
    for method, color in zip(methods, colors):
        bars = ax.bar(x + width / 2 if method == "Finetuning" else x - width / 2, 
               [overall_acc[method][i], precision[method][i], recall[method][i], f1[method][i], auc[method][i]], 
               width, label=method, color=color)
        
        # 在柱体上方显示数值
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height), xytext=(0, 3),
                        textcoords="offset points", ha='center', va='bottom')

    ax.set_ylabel(cat)
    ax.set_xticks(x)
    ax.set_xticklabels(["Overall Acc", "Precision", "Recall", "F1", "AUC"])
    ax.set_ylim(50, 100)
    ax.legend()

# 标题
plt.suptitle('Comparison between "Train from scratch" and "Finetuning"', fontsize=16)

# 显示图形
# plt.show()
plt.savefig("comparison_plot_18.png")

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
categories = ["Black-box", "Correct", "Confidence", "Entropy", "Modified Entropy"]
methods = ["Train from scratch", "Finetuning"]

overall_acc = {
    "Train from scratch": [72.945, 69.3, 77.3, 72.9, 77.3],
    "Finetuning": [54.575, 51.8, 56.4, 56.2, 56.5]
}

precision = {
    "Train from scratch": [67.1, 62, 70.5, 67.8, 70.5],
    "Finetuning": [52.7, 50.9, 53.9, 53.8, 53.9]
}

recall = {
    "Train from scratch":  [89.9, 100, 93.8, 87, 93.8],
    "Finetuning": [90, 100, 87.5, 86.5, 89]
}

f1 = {
    "Train from scratch": [76.9, 76.5, 80.5, 76.2, 80.5],
    "Finetuning": [66.4, 67.5, 66.8, 66.4, 67.1]
}

auc = {
    "Train from scratch": [77.8, 69.3, 79.2, 75.9, 79.2],
    "Finetuning": [55.7, 51.8, 56.6, 56.6, 56.6]
}

# 设置子图
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(8, 20))

# 颜色
colors = ['#1f77b4', '#ff7f0e']

# 绘制柱状图
for i, cat in enumerate(categories):
    ax = axes[i]
    x = np.arange(len(categories))
    width = 0.35
    for method, color in zip(methods, colors):
        bars = ax.bar(x + width / 2 if method == "Finetuning" else x - width / 2, 
               [overall_acc[method][i], precision[method][i], recall[method][i], f1[method][i], auc[method][i]], 
               width, label=method, color=color)
        
        # 在柱体上方显示数值
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height), xytext=(0, 3),
                        textcoords="offset points", ha='center', va='bottom')

    ax.set_ylabel(cat)
    ax.set_xticks(x)
    ax.set_xticklabels(["Overall Acc", "Precision", "Recall", "F1", "AUC"])
    ax.set_ylim(50, 100)
    ax.legend()

# 标题
plt.suptitle('Comparison between "Train from scratch" and "Finetuning"', fontsize=16)

# 显示图形
# plt.show()
plt.savefig("comparison_plot_vit.png")

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

# 读取两张图片
image1 = imread('/data/home/whh/MLHospital/mlh/examples/comparison_plot_18.png')
image2 = imread('/data/home/whh/MLHospital/mlh/examples/comparison_plot_101.png')

# 创建一个新的图形
fig = plt.figure(figsize=(12, 5))

# 添加第一个子图，标题为ResNet18
ax1 = fig.add_subplot(1, 2, 1)
ax1.imshow(image1)
ax1.set_title('ResNet18')

# 添加第二个子图，标题为Wide_ResNet_101_2
ax2 = fig.add_subplot(1, 2, 2)
ax2.imshow(image2)
ax2.set_title('Wide_ResNet_101_2')

# 隐藏坐标轴
ax1.axis('off')
ax2.axis('off')

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
categories = ["Black-box", "Correct", "Confidence", "Entropy", "Modified Entropy"]
methods = ["Train from scratch", "Finetuning"]

overall_acc = {
    "Train from scratch": [0.6375, 0.658, 0.69, 0.642, 0.69],
    "Finetuning": [0.6272, 0.611, 0.654, 0.632, 0.655]
}

precision = {
    "Train from scratch": [0.597, 0.596, 0.635, 0.61, 0.636],
    "Finetuning": [0.582, 0.562, 0.605, 0.591, 0.605]
}

recall = {
    "Train from scratch": [0.843, 0.982, 0.895, 0.786, 0.886],
    "Finetuning": [0.903, 0.995, 0.89, 0.856, 0.891]
}

f1 = {
    "Train from scratch": [0.699, 0.742, 0.743, 0.687, 0.74],
    "Finetuning": [0.708, 0.719, 0.72, 0.699, 0.721]
}

auc = {
    "Train from scratch": [0.673, 0.658, 0.707, 0.66, 0.707],
    "Finetuning": [0.654, 0.611, 0.658, 0.638, 0.658]
}

# 转换为百分比
for method in methods:
    overall_acc[method] = [acc * 100 for acc in overall_acc[method]]
    precision[method] = [prec * 100 for prec in precision[method]]
    recall[method] = [rec * 100 for rec in recall[method]]
    f1[method] = [f * 100 for f in f1[method]]
    auc[method] = [a * 100 for a in auc[method]]

# 设置子图
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(8, 20))

# 颜色
colors = ['#1f77b4', '#ff7f0e']

# 绘制柱状图
for i, cat in enumerate(categories):
    ax = axes[i]
    x = np.arange(len(categories))
    width = 0.35
    for method, color in zip(methods, colors):
        bars = ax.bar(x + width / 2 if method == "Finetuning" else x - width / 2, 
               [overall_acc[method][i], precision[method][i], recall[method][i], f1[method][i], auc[method][i]], 
               width, label=method, color=color)
        
        # 在柱体上方显示数值
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.2f}%', xy=(bar.get_x() + bar.get_width() / 2, height), xytext=(0, 3),
                        textcoords="offset points", ha='center', va='bottom')

    ax.set_ylabel(cat)
    ax.set_xticks(x)
    ax.set_xticklabels(["Overall Acc", "Precision", "Recall", "F1", "AUC"])
    ax.set_ylim(50, 100)  # 设置纵坐标范围
    ax.legend()

# 标题
plt.suptitle('Comparison between "Train from scratch" and "Finetuning"', fontsize=16)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
categories = ["Black-box", "Correct", "Confidence", "Entropy", "Modified Entropy"]
methods = ["Train from scratch", "Finetuning"]

overall_acc = {
    "Train from scratch": [0.6375, 0.658, 0.69, 0.642, 0.69],
    "Finetuning": [0.6272, 0.611, 0.654, 0.632, 0.655]
}

precision = {
    "Train from scratch": [0.597, 0.596, 0.635, 0.61, 0.636],
    "Finetuning": [0.582, 0.562, 0.605, 0.591, 0.605]
}

recall = {
    "Train from scratch": [0.843, 0.982, 0.895, 0.786, 0.886],
    "Finetuning": [0.903, 0.995, 0.89, 0.856, 0.891]
}

f1 = {
    "Train from scratch": [0.699, 0.742, 0.743, 0.687, 0.74],
    "Finetuning": [0.708, 0.719, 0.72, 0.699, 0.721]
}

auc = {
    "Train from scratch": [0.673, 0.658, 0.707, 0.66, 0.707],
    "Finetuning": [0.654, 0.611, 0.658, 0.638, 0.658]
}

# 转换为百分比
for method in methods:
    overall_acc[method] = [acc * 100 for acc in overall_acc[method]]
    precision[method] = [prec * 100 for prec in precision[method]]
    recall[method] = [rec * 100 for rec in recall[method]]
    f1[method] = [f * 100 for f in f1[method]]
    auc[method] = [a * 100 for a in auc[method]]

# 设置子图
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(8, 20))

# 颜色
colors = ['#1f77b4', '#ff7f0e']

# 绘制柱状图
for i, cat in enumerate(categories):
    ax = axes[i]
    x = np.arange(len(categories))
    width = 0.35
    for method, color in zip(methods, colors):
        bars = ax.bar(x + width / 2 if method == "Finetuning" else x - width / 2, 
               [overall_acc[method][i], precision[method][i], recall[method][i], f1[method][i], auc[method][i]], 
               width, label=method, color=color)
        
        # 在柱体上方显示数值
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.2f}%', xy=(bar.get_x() + bar.get_width() / 2, height), xytext=(0, 3),
                        textcoords="offset points", ha='center', va='bottom')

    ax.set_ylabel(cat)
    ax.set_xticks(x)
    ax.set_xticklabels(["Overall Acc", "Precision", "Recall", "F1", "AUC"])
    ax.legend()

    # 设置纵坐标从50%开始
    ax.set_ylim(50, 100)

# 标题
plt.suptitle('Comparison between "Train from scratch" and "Finetuning"', fontsize=16)

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
categories = ["Black-box", "Correct", "Confidence", "Entropy", "Modified Entropy"]
methods = ["Train from scratch", "Finetuning"]

overall_acc = {
    "Train from scratch": [0.6375, 0.658, 0.69, 0.642, 0.69],
    "Finetuning": [0.6272, 0.611, 0.654, 0.632, 0.655]
}

precision = {
    "Train from scratch": [0.597, 0.596, 0.635, 0.61, 0.636],
    "Finetuning": [0.582, 0.562, 0.605, 0.591, 0.605]
}

recall = {
    "Train from scratch": [0.843, 0.982, 0.895, 0.786, 0.886],
    "Finetuning": [0.903, 0.995, 0.89, 0.856, 0.891]
}

f1 = {
    "Train from scratch": [0.699, 0.742, 0.743, 0.687, 0.74],
    "Finetuning": [0.708, 0.719, 0.72, 0.699, 0.721]
}

auc = {
    "Train from scratch": [0.673, 0.658, 0.707, 0.66, 0.707],
    "Finetuning": [0.654, 0.611, 0.658, 0.638, 0.658]
}

# 设置子图
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(8, 20))

# 颜色
colors = ['#1f77b4', '#ff7f0e']

# 绘制柱状图
for i, cat in enumerate(categories):
    ax = axes[i]
    x = np.arange(len(categories))
    width = 0.35
    for method, color in zip(methods, colors):
        bars = ax.bar(x + width / 2 if method == "Finetuning" else x - width / 2, 
               [overall_acc[method][i], precision[method][i], recall[method][i], f1[method][i], auc[method][i]], 
               width, label=method, color=color)
        
        # 在柱体上方显示数值
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height), xytext=(0, 3),
                        textcoords="offset points", ha='center', va='bottom')

    ax.set_ylabel(cat)
    ax.set_xticks(x)
    ax.set_xticklabels(["Overall Acc", "Precision", "Recall", "F1", "AUC"])
    ax.legend()

    # 设置纵坐标从50%开始
    ax.set_ylim(50, 100)

    # 设置 y 轴标签
    y_labels = [f"{int(y)}%" for y in ax.get_yticks()]
    ax.set_yticklabels(y_labels)
    ax.yaxis.set_major_locator(plt.FixedLocator(ax.get_yticks()))

# 标题
plt.suptitle('Comparison between "Train from scratch" and "Finetuning"', fontsize=16)

# 显示图形
plt.show()
# Out:
# /tmp/ipykernel_1178886/4056655409.py:65: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(y_labels)
